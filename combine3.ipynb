# %%
import os
import glob
import pandas as pd
os.chdir("resources/3")

# %%
df = pd.read_csv('03-22-2020.csv')
df.head()
# Out:
#       FIPS         Admin2 Province_State Country_Region    Last_Update  \
# 0  36061.0  New York City       New York             US  3/22/20 23:45
# 1  36059.0         Nassau       New York             US  3/22/20 23:45
# 2  36119.0    Westchester       New York             US  3/22/20 23:45
# 3  36103.0        Suffolk       New York             US  3/22/20 23:45
# 4  36087.0       Rockland       New York             US  3/22/20 23:45
#
#          Lat      Long_  Confirmed  Deaths  Recovered  Active  \
# 0  40.767273 -73.971526       9654      63          0       0
# 1  40.740665 -73.589419       1900       4          0       0
# 2  41.162784 -73.757417       1873       0          0       0
# 3  40.883201 -72.801217       1034       9          0       0
# 4  41.150279 -74.025605        455       1          0       0
#
#                   Combined_Key
# 0  New York City, New York, US
# 1         Nassau, New York, US
# 2    Westchester, New York, US
# 3        Suffolk, New York, US
# ...

# %%
df1 = pd.read_csv('03-22-2020.csv')
df2 = pd.read_csv('03-23-2020.csv')
df3 = pd.read_csv('03-24-2020.csv')
df4 = pd.read_csv('03-25-2020.csv')
df5 = pd.read_csv('03-26-2020.csv')
df6 = pd.read_csv('03-27-2020.csv')
df1.head()
# Out:
#       FIPS         Admin2 Province_State Country_Region    Last_Update  \
# 0  36061.0  New York City       New York             US  3/22/20 23:45
# 1  36059.0         Nassau       New York             US  3/22/20 23:45
# 2  36119.0    Westchester       New York             US  3/22/20 23:45
# 3  36103.0        Suffolk       New York             US  3/22/20 23:45
# 4  36087.0       Rockland       New York             US  3/22/20 23:45
#
#          Lat      Long_  Confirmed  Deaths  Recovered  Active  \
# 0  40.767273 -73.971526       9654      63          0       0
# 1  40.740665 -73.589419       1900       4          0       0
# 2  41.162784 -73.757417       1873       0          0       0
# 3  40.883201 -72.801217       1034       9          0       0
# 4  41.150279 -74.025605        455       1          0       0
#
#                   Combined_Key
# 0  New York City, New York, US
# 1         Nassau, New York, US
# 2    Westchester, New York, US
# 3        Suffolk, New York, US
# ...

# %%
#Use glob to match the pattern ‘csv’
#extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format('csv'))]

# %%
#Combine all files in the list
data3= pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
data3.head(2)
# Out:
#       FIPS         Admin2 Province_State Country_Region    Last_Update  \
# 0  36061.0  New York City       New York             US  3/22/20 23:45
# 1  36059.0         Nassau       New York             US  3/22/20 23:45
#
#          Lat      Long_  Confirmed  Deaths  Recovered  Active  \
# 0  40.767273 -73.971526       9654      63          0       0
# 1  40.740665 -73.589419       1900       4          0       0
#
#                   Combined_Key
# 0  New York City, New York, US
# 1         Nassau, New York, US

# %%
data = data3.drop(['Active', 'Admin2','Combined_Key', 'FIPS'], axis = 1)
data.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
data.columns = ['Province/State', 'Country/Region', 'Last_Update', 'Latitude', 'Longitude',
       'Confirmed', 'Deaths', 'Recovered']
data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Last_Update', 'Latitude',
#        'Longitude', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
data.head(2)
# Out:
#   Province/State Country/Region    Last_Update   Latitude  Longitude  \
# 0       New York             US  3/22/20 23:45  40.767273 -73.971526
# 1       New York             US  3/22/20 23:45  40.740665 -73.589419
#
#    Confirmed  Deaths  Recovered
# 0       9654      63          0
# 1       1900       4          0

# %%
#export to csv
data.to_csv( "../combined3.csv", index=False, encoding='utf-8-sig')
