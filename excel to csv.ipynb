# %%
import pandas as pd

# %%
df1 = pd.read_excel('resources/1/2019-01-10 to 01-20.xlsx')
df1.head()
# Out:
#   Province/State Country/Region             Last Update  Confirmed  Deaths  \
# 0          Hubei          China  1/11/2020  22:00:00 AM         41       1
# 1          Hubei          China  1/12/2020  22:00:00 AM         41       1
# 2          Hubei          China  1/13/2020  22:00:00 AM         41       1
# 3          Hubei          China  1/14/2020  22:00:00 AM         41       1
# 4          Hubei          China  1/15/2020  22:00:00 AM         41       1
#
#    Recovered  new_confirmed
# 0          2              0
# 1          6              0
# 2          7              0
# 3          7              0
# 4          7              0

# %%
df2 = df1.drop(['new_confirmed'], axis =1)
df2
# Out:
#    Province/State Country/Region              Last Update  Confirmed  Deaths  \
# 0           Hubei          China   1/11/2020  22:00:00 AM         41       1
# 1           Hubei          China   1/12/2020  22:00:00 AM         41       1
# 2           Hubei          China   1/13/2020  22:00:00 AM         41       1
# 3           Hubei          China   1/14/2020  22:00:00 AM         41       1
# 4           Hubei          China   1/15/2020  22:00:00 AM         41       1
# 5           Hubei          China   1/16/2020  22:00:00 PM         41       2
# 6           Hubei          China   1/17/2020  22:00:00 PM         45       2
# 7           Hubei          China   1/18/2020  22:00:00 PM         62       2
# 8           Hubei          China  1/198/2020  22:00:00 PM        121       3
# 9           Hubei          China   1/20/2020  22:00:00 PM        198       3
# 10          Hubei          China   1/21/2020  22:00:00 PM        270       3
# ...

# %%
df2.to_csv('resources/1/2019-01-10 to 01-20.csv')
