# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd

# %%
covid = pd.read_csv("COVID19.CSV")

# %%
covid.head()
# Out:
#    Unnamed: 0       Date  ISO_CountryID  Country/Region ISO_CountryName  \
# 0         0.0  1/22/2020            156  Mainland China           China
# 1         1.0  1/22/2020            156  Mainland China           China
# 2         2.0  1/22/2020            156  Mainland China           China
# 3         3.0  1/22/2020            156  Mainland China           China
# 4         4.0  1/22/2020            156  Mainland China           China
#
#   Province_Id Province/State      Last Update  Confirmed  Deaths  Recovered  \
# 0       156-8          Anhui  1/22/2020 17:00        1.0     NaN        NaN
# 1      156-15        Beijing  1/22/2020 17:00       14.0     NaN        NaN
# 2      156-35      Chongqing  1/22/2020 17:00        6.0     NaN        NaN
# 3      156-76         Fujian  1/22/2020 17:00        1.0     NaN        NaN
# 4      156-78          Gansu  1/22/2020 17:00        NaN     NaN        NaN
#
#   ISO_2 ISO_3  Latitude  Longitude
# 0    CN   CHN       NaN        NaN
# ...
