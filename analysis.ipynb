# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('resources/fdata.csv')
df.head()
# Out:
#    Confirmed Country_Region  Deaths      Last_Update  Latitude  Longitude  \
# 0        1.0          China     0.0  1/22/2020 17:00   30.6007   117.9249
# 1       14.0          China     0.0  1/22/2020 17:00   40.2374   116.2305
# 2        6.0          China     0.0  1/22/2020 17:00   29.4316   106.9123
# 3        1.0          China     0.0  1/22/2020 17:00   26.4837   117.9249
# 4        0.0          China     0.0  1/22/2020 17:00   35.7518   104.2861
#
#   Province_State  Recovered
# 0          Anhui        0.0
# 1        Beijing        0.0
# 2      Chongqing        0.0
# 3         Fujian        0.0
# 4          Gansu        0.0

# %%
df1 = df.set_index('Country_Region')
#df2= df.set_index(['Country_Region','Last_Update'])
df1
# Out:
#                     Confirmed  Deaths          Last_Update   Latitude  \
# Country_Region
# China                     1.0     0.0      1/22/2020 17:00  30.600700
# China                    14.0     0.0      1/22/2020 17:00  40.237400
# China                     6.0     0.0      1/22/2020 17:00  29.431600
# China                     1.0     0.0      1/22/2020 17:00  26.483700
# China                     0.0     0.0      1/22/2020 17:00  35.751800
# ...                       ...     ...                  ...        ...
# West Bank and Gaza      374.0     2.0  2020-04-15 22:56:32  31.952200
# Western Sahara            6.0     0.0  2020-04-15 22:56:32  24.215500
# Yemen                     1.0     0.0  2020-04-15 22:56:32  15.552727
# Zambia                   48.0     2.0  2020-04-15 22:56:32 -13.133897
# Zimbabwe                 23.0     3.0  2020-04-15 22:56:32 -19.015438
#
#                      Longitude Province_State  Recovered
# Country_Region
# ...

# %%
China = df1.filter(like='China', axis=0)
len(China)
# Out:
# 2724

# %%
df.describe()

# %%
country = df.groupby('Country_Region')

# %%
country.mean().sort_values(by=['Confirmed','Deaths'], ascending=False, na_position='first')

# %%
China.to_csv('resources/China_csv')
