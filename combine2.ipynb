# %%
import os
import glob
import pandas as pd
import numpy as np
os.chdir("resources/2")

# %%
#have to read all files to update the date of each form.
#due to some certain rows were note updated when there is no change.

df1 = pd.read_csv('03-01-2020.csv')
df2 = pd.read_csv('03-02-2020.csv')
df3 = pd.read_csv('03-03-2020.csv')
df4 = pd.read_csv('03-04-2020.csv')
df5 = pd.read_csv('03-05-2020.csv')
df6 = pd.read_csv('03-06-2020.csv')
df7 = pd.read_csv('03-07-2020.csv')
df8 = pd.read_csv('03-08-2020.csv')
df9 = pd.read_csv('03-09-2020.csv')
df10 = pd.read_csv('03-10-2020.csv')
df11 = pd.read_csv('03-11-2020.csv')
df12 = pd.read_csv('03-12-2020.csv')
df13 = pd.read_csv('03-13-2020.csv')
df14 = pd.read_csv('03-14-2020.csv')
df15 = pd.read_csv('03-15-2020.csv')
df16 = pd.read_csv('03-16-2020.csv')
df17 = pd.read_csv('03-17-2020.csv')
df18 = pd.read_csv('03-18-2020.csv')
df19 = pd.read_csv('03-19-2020.csv')
df20 = pd.read_csv('03-20-2020.csv')
df21 = pd.read_csv('03-21-2020.csv')
df1.head()
# Out:
#   Province/State  Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2020-03-01T10:13:19      66907    2761
# 1            NaN     South Korea  2020-03-01T23:43:03       3736      17
# 2            NaN           Italy  2020-03-01T23:23:02       1694      34
# 3      Guangdong  Mainland China  2020-03-01T14:13:18       1349       7
# 4          Henan  Mainland China  2020-03-01T14:13:18       1272      22
#
#    Recovered  Latitude  Longitude
# 0      31536   30.9756   112.2707
# 1         30   36.0000   128.0000
# 2         83   43.0000    12.0000
# 3       1016   23.3417   113.4244
# 4       1198   33.8820   113.6140

# %%
#update date of each file
df1['Last Update']= '2020-03-01'
df2['Last Update'] = '2020-03-02'
df3['Last Update'] = '2020-03-03'
df4['Last Update'] = '2020-03-04'
df5['Last Update'] = '2020-03-05'
df6['Last Update'] = '2020-03-06'
df7['Last Update'] = '2020-03-07'
df8['Last Update'] = '2020-03-08'
df9['Last Update'] = '2020-03-09'
df10['Last Update'] = '2020-03-10'
df11['Last Update'] = '2020-03-11'
df12['Last Update'] = '2020-03-12'
df13['Last Update'] = '2020-03-13'
df14['Last Update'] = '2020-03-14'
df15['Last Update'] = '2020-03-15'
df16['Last Update'] = '2020-03-16'
df17['Last Update'] = '2020-03-17'
df18['Last Update'] = '2020-03-18'
df19['Last Update'] = '2020-03-19'
df20['Last Update'] = '2020-03-20'
df21['Last Update'] = '2020-03-21'

df2.head(2)
# Out:
#   Province/State  Country/Region Last Update  Confirmed  Deaths  Recovered  \
# 0          Hubei  Mainland China  2020-03-02      67103    2803      33934
# 1            NaN     South Korea  2020-03-02       4335      28         30
#
#    Latitude  Longitude
# 0   30.9756   112.2707
# 1   36.0000   128.0000

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21])
df
# Out:
#     Province/State         Country/Region Last Update  Confirmed  Deaths  \
# 0            Hubei         Mainland China  2020-03-01      66907    2761
# 1              NaN            South Korea  2020-03-01       3736      17
# 2              NaN                  Italy  2020-03-01       1694      34
# 3        Guangdong         Mainland China  2020-03-01       1349       7
# 4            Henan         Mainland China  2020-03-01       1272      22
# ..             ...                    ...         ...        ...     ...
# 299            NaN                 Jersey  2020-03-21          0       0
# 300            NaN            Puerto Rico  2020-03-21          0       0
# 301            NaN  Republic of the Congo  2020-03-21          0       0
# 302            NaN            The Bahamas  2020-03-21          0       0
# 303            NaN             The Gambia  2020-03-21          0       0
#
#      Recovered  Latitude  Longitude
# 0        31536   30.9756   112.2707
# ...

# %%
#Use glob to match the pattern ‘csv’
#extension = 'csv'
#all_filenames = [i for i in glob.glob('*.{}'.format('csv'))]
#Combine all files in the list
#mar = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
df.rename(columns={'Last Update':'Last_Update','Province/State':'Province_State','Country/Region':'Country_Region'}, inplace=True) 
df.head(2)
# Out:
#   Province_State  Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 0          Hubei  Mainland China  2020-03-01      66907    2761      31536
# 1            NaN     South Korea  2020-03-01       3736      17         30
#
#    Latitude  Longitude
# 0   30.9756   112.2707
# 1   36.0000   128.0000

# %%
#mar['Row_Num'] = np.arange(len(mar))

# %%
df[df['Province_State']=='Gansu']
# Out:
#     Province_State  Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 34           Gansu  Mainland China  2020-03-01         91       2         84
# 35           Gansu  Mainland China  2020-03-02         91       2         85
# 35           Gansu  Mainland China  2020-03-03         91       2         86
# 35           Gansu  Mainland China  2020-03-04         91       2         87
# 36           Gansu  Mainland China  2020-03-05        102       2         87
# 36           Gansu  Mainland China  2020-03-06        119       2         87
# 39           Gansu  Mainland China  2020-03-07        120       2         87
# 39           Gansu  Mainland China  2020-03-08        124       2         87
# 40           Gansu  Mainland China  2020-03-09        124       2         88
# 44           Gansu  Mainland China  2020-03-10        125       2         88
# 46           Gansu           China  2020-03-11        127       2         88
# ...

# %%
df.loc[df.Province_State == 'Gansu', "Latitude"] = 36.0611
df.loc[df.Province_State == 'Gansu', "Longitude"] = 103.8343
df.loc[df.Province_State == 'Gansu', "Country_Region"] = 'Mainland China'
df[df['Province_State']=='Gansu']
# Out:
#     Province_State  Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 34           Gansu  Mainland China  2020-03-01         91       2         84
# 35           Gansu  Mainland China  2020-03-02         91       2         85
# 35           Gansu  Mainland China  2020-03-03         91       2         86
# 35           Gansu  Mainland China  2020-03-04         91       2         87
# 36           Gansu  Mainland China  2020-03-05        102       2         87
# 36           Gansu  Mainland China  2020-03-06        119       2         87
# 39           Gansu  Mainland China  2020-03-07        120       2         87
# 39           Gansu  Mainland China  2020-03-08        124       2         87
# 40           Gansu  Mainland China  2020-03-09        124       2         88
# 44           Gansu  Mainland China  2020-03-10        125       2         88
# 46           Gansu  Mainland China  2020-03-11        127       2         88
# ...

# %%
df[df['Province_State']=='Gansu'].dropna()
df[df['Province_State']=='Gansu']
# Out:
#     Province_State  Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 34           Gansu  Mainland China  2020-03-01         91       2         84
# 35           Gansu  Mainland China  2020-03-02         91       2         85
# 35           Gansu  Mainland China  2020-03-03         91       2         86
# 35           Gansu  Mainland China  2020-03-04         91       2         87
# 36           Gansu  Mainland China  2020-03-05        102       2         87
# 36           Gansu  Mainland China  2020-03-06        119       2         87
# 39           Gansu  Mainland China  2020-03-07        120       2         87
# 39           Gansu  Mainland China  2020-03-08        124       2         87
# 40           Gansu  Mainland China  2020-03-09        124       2         88
# 44           Gansu  Mainland China  2020-03-10        125       2         88
# 46           Gansu  Mainland China  2020-03-11        127       2         88
# ...

# %%
df.drop([206,211], axis = 0, inplace = True)
df[df['Province_State']=='Gansu']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-658bd40134ee> in <module>
# ----> 1 df.drop([206,211], axis = 0, inplace = True)
#       2 df[df['Province_State']=='Gansu']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df.loc[df.Province_State == 'Hebei', "Latitude"] = 38.0428
df.loc[df.Province_State == 'Hebei', "Longitude"] = 114.5149
df.loc[df.Province_State == 'Hebei', "Country_Region"] = 'Mainland China'
df[df['Province_State']=='Hebei']
# Out:
#     Province_State  Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 18           Hebei  Mainland China  2020-03-01        318       6        294
# 18           Hebei  Mainland China  2020-03-02        318       6        296
# 18           Hebei  Mainland China  2020-03-03        318       6        300
# 19           Hebei  Mainland China  2020-03-04        318       6        301
# 21           Hebei  Mainland China  2020-03-05        318       6        304
# 22           Hebei  Mainland China  2020-03-06        318       6        305
# 22           Hebei  Mainland China  2020-03-07        318       6        307
# 23           Hebei  Mainland China  2020-03-08        318       6        307
# 25           Hebei  Mainland China  2020-03-09        318       6        307
# 27           Hebei  Mainland China  2020-03-10        318       6        307
# 29           Hebei  Mainland China  2020-03-11        318       6        307
# ...

# %%
df.drop([207,212], axis = 0, inplace = True)
df[df['Province_State']=='Hebei']
# Out:
#    Province_State  Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 18          Hebei  Mainland China  2020-03-01        318       6        294
# 18          Hebei  Mainland China  2020-03-02        318       6        296
# 18          Hebei  Mainland China  2020-03-03        318       6        300
# 19          Hebei  Mainland China  2020-03-04        318       6        301
# 21          Hebei  Mainland China  2020-03-05        318       6        304
# 22          Hebei  Mainland China  2020-03-06        318       6        305
# 22          Hebei  Mainland China  2020-03-07        318       6        307
# 23          Hebei  Mainland China  2020-03-08        318       6        307
# 25          Hebei  Mainland China  2020-03-09        318       6        307
# 27          Hebei  Mainland China  2020-03-10        318       6        307
# 29          Hebei  Mainland China  2020-03-11        318       6        307
# ...

# %%
df[df['Country_Region']=='Japan']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 20             NaN          Japan  2020-03-01        256       6         32
# 20             NaN          Japan  2020-03-02        274       6         32
# 20             NaN          Japan  2020-03-03        293       6         43
# 18             NaN          Japan  2020-03-04        331       6         43
# 19             NaN          Japan  2020-03-05        360       6         43
# 19             NaN          Japan  2020-03-06        420       6         46
# 19             NaN          Japan  2020-03-07        461       6         76
# 18             NaN          Japan  2020-03-08        502       6         76
# 18             NaN          Japan  2020-03-09        511      17         76
# 16             NaN          Japan  2020-03-10        581      10        101
# 16             NaN          Japan  2020-03-11        639      15        118
# ...

# %%
df.loc[df.Country_Region == 'Japan', "Latitude"] = 36.2048
df.loc[df.Country_Region == 'Japan', "Longitude"] = 138.2529
df.loc[df.Country_Region == 'Japan', "Province_State"] ='Japan'
df[df['Country_Region']=='Japan']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 20           Japan          Japan  2020-03-01        256       6         32
# 20           Japan          Japan  2020-03-02        274       6         32
# 20           Japan          Japan  2020-03-03        293       6         43
# 18           Japan          Japan  2020-03-04        331       6         43
# 19           Japan          Japan  2020-03-05        360       6         43
# 19           Japan          Japan  2020-03-06        420       6         46
# 19           Japan          Japan  2020-03-07        461       6         76
# 18           Japan          Japan  2020-03-08        502       6         76
# 18           Japan          Japan  2020-03-09        511      17         76
# 16           Japan          Japan  2020-03-10        581      10        101
# 16           Japan          Japan  2020-03-11        639      15        118
# ...

# %%
df[df['Country_Region']=='South Korea']
# Out:
#   Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 1            NaN    South Korea  2020-03-01       3736      17         30
# 1            NaN    South Korea  2020-03-02       4335      28         30
# 1            NaN    South Korea  2020-03-03       5186      28         30
# 1            NaN    South Korea  2020-03-04       5621      35         41
# 1            NaN    South Korea  2020-03-05       6088      35         41
# 1            NaN    South Korea  2020-03-06       6593      42        135
# 1            NaN    South Korea  2020-03-07       7041      44        135
# 2            NaN    South Korea  2020-03-08       7314      50        118
# 2            NaN    South Korea  2020-03-09       7478      53        118
#
#    Latitude  Longitude
# 1      36.0      128.0
# 1      36.0      128.0
# 1      36.0      128.0
# 1      36.0      128.0
# 1      36.0      128.0
# 1      36.0      128.0
# 1      36.0      128.0
# 2      36.0      128.0
# ...

# %%
df.loc[df.Country_Region == 'South Korea', "Latitude"] = 35.9078
df.loc[df.Country_Region == 'South Korea', "Longitude"] = 127.7669
df.loc[df.Country_Region == 'South Korea', "Province_State"] = 'South Korea'
df[df['Country_Region']=='South Korea']
# Out:
#   Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 1    South Korea    South Korea  2020-03-01       3736      17         30
# 1    South Korea    South Korea  2020-03-02       4335      28         30
# 1    South Korea    South Korea  2020-03-03       5186      28         30
# 1    South Korea    South Korea  2020-03-04       5621      35         41
# 1    South Korea    South Korea  2020-03-05       6088      35         41
# 1    South Korea    South Korea  2020-03-06       6593      42        135
# 1    South Korea    South Korea  2020-03-07       7041      44        135
# 2    South Korea    South Korea  2020-03-08       7314      50        118
# 2    South Korea    South Korea  2020-03-09       7478      53        118
#
#    Latitude  Longitude
# 1   35.9078   127.7669
# 1   35.9078   127.7669
# 1   35.9078   127.7669
# 1   35.9078   127.7669
# 1   35.9078   127.7669
# 1   35.9078   127.7669
# 1   35.9078   127.7669
# 2   35.9078   127.7669
# ...

# %%
df[df['Country_Region']=='Thailand']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 42            NaN       Thailand  2020-03-01         42       1         28
# 42            NaN       Thailand  2020-03-02         43       1         31
# 44            NaN       Thailand  2020-03-03         43       1         31
# 46            NaN       Thailand  2020-03-04         43       1         31
# 49            NaN       Thailand  2020-03-05         47       1         31
# 50            NaN       Thailand  2020-03-06         48       1         31
# 53            NaN       Thailand  2020-03-07         50       1         31
# 54            NaN       Thailand  2020-03-08         50       1         31
# 56            NaN       Thailand  2020-03-09         50       1         31
# 62            NaN       Thailand  2020-03-10         53       1         33
# 68            NaN       Thailand  2020-03-11         59       1         34
# ...

# %%
df.loc[df.Country_Region == 'Thailand', "Latitude"] = 15.87
df.loc[df.Country_Region == 'Thailand', "Longitude"] = 100.9925
df.loc[df.Country_Region == 'Thailand', "Province_State"] = 'Thailand'
df[df['Country_Region']=='Thailand']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 42       Thailand       Thailand  2020-03-01         42       1         28
# 42       Thailand       Thailand  2020-03-02         43       1         31
# 44       Thailand       Thailand  2020-03-03         43       1         31
# 46       Thailand       Thailand  2020-03-04         43       1         31
# 49       Thailand       Thailand  2020-03-05         47       1         31
# 50       Thailand       Thailand  2020-03-06         48       1         31
# 53       Thailand       Thailand  2020-03-07         50       1         31
# 54       Thailand       Thailand  2020-03-08         50       1         31
# 56       Thailand       Thailand  2020-03-09         50       1         31
# 62       Thailand       Thailand  2020-03-10         53       1         33
# 68       Thailand       Thailand  2020-03-11         59       1         34
# ...

# %%
df[df['Country_Region']=='Malaysia']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 45             NaN       Malaysia  2020-03-01         29       0         18
# 46             NaN       Malaysia  2020-03-02         29       0         18
# 46             NaN       Malaysia  2020-03-03         36       0         22
# 44             NaN       Malaysia  2020-03-04         50       0         22
# 48             NaN       Malaysia  2020-03-05         50       0         22
# 42             NaN       Malaysia  2020-03-06         83       0         22
# 42             NaN       Malaysia  2020-03-07         93       0         23
# 42             NaN       Malaysia  2020-03-08         99       0         24
# 41             NaN       Malaysia  2020-03-09        117       0         24
# 43             NaN       Malaysia  2020-03-10        129       0         24
# 42             NaN       Malaysia  2020-03-11        149       0         26
# ...

# %%
df.loc[df.Country_Region == 'Malaysia', "Latitude"] = 4.2105
df.loc[df.Country_Region == 'Malaysia', "Longitude"] = 101.9758
df.loc[df.Country_Region == 'Malaysia', "Province_State"] = 'Malaysia'
df[df['Country_Region']=='Malaysia']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 45        Malaysia       Malaysia  2020-03-01         29       0         18
# 46        Malaysia       Malaysia  2020-03-02         29       0         18
# 46        Malaysia       Malaysia  2020-03-03         36       0         22
# 44        Malaysia       Malaysia  2020-03-04         50       0         22
# 48        Malaysia       Malaysia  2020-03-05         50       0         22
# 42        Malaysia       Malaysia  2020-03-06         83       0         22
# 42        Malaysia       Malaysia  2020-03-07         93       0         23
# 42        Malaysia       Malaysia  2020-03-08         99       0         24
# 41        Malaysia       Malaysia  2020-03-09        117       0         24
# 43        Malaysia       Malaysia  2020-03-10        129       0         24
# 42        Malaysia       Malaysia  2020-03-11        149       0         26
# ...

# %%
df[df['Country_Region']=='Singapore']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 31             NaN      Singapore  2020-03-01        106       0         72
# 32             NaN      Singapore  2020-03-02        108       0         78
# 32             NaN      Singapore  2020-03-03        110       0         78
# 32             NaN      Singapore  2020-03-04        110       0         78
# 32             NaN      Singapore  2020-03-05        117       0         78
# 33             NaN      Singapore  2020-03-06        130       0         78
# 35             NaN      Singapore  2020-03-07        138       0         78
# 34             NaN      Singapore  2020-03-08        150       0         78
# 34             NaN      Singapore  2020-03-09        150       0         78
# 38             NaN      Singapore  2020-03-10        160       0         78
# 38             NaN      Singapore  2020-03-11        178       0         96
# ...

# %%
df.loc[df.Country_Region == 'Singapore', "Latitude"] = 1.3521
df.loc[df.Country_Region == 'Singapore', "Longitude"] = 103.8198
df.loc[df.Country_Region == 'Singapore', "Province_State"] = 'Singapore'
df[df['Country_Region']=='Singapore']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 31       Singapore      Singapore  2020-03-01        106       0         72
# 32       Singapore      Singapore  2020-03-02        108       0         78
# 32       Singapore      Singapore  2020-03-03        110       0         78
# 32       Singapore      Singapore  2020-03-04        110       0         78
# 32       Singapore      Singapore  2020-03-05        117       0         78
# 33       Singapore      Singapore  2020-03-06        130       0         78
# 35       Singapore      Singapore  2020-03-07        138       0         78
# 34       Singapore      Singapore  2020-03-08        150       0         78
# 34       Singapore      Singapore  2020-03-09        150       0         78
# 38       Singapore      Singapore  2020-03-10        160       0         78
# 38       Singapore      Singapore  2020-03-11        178       0         96
# ...

# %%
df[df['Country_Region']=='Philippines']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 78             NaN    Philippines  2020-03-01          3       1          1
# 84             NaN    Philippines  2020-03-02          3       1          1
# 85             NaN    Philippines  2020-03-03          3       1          1
# 94             NaN    Philippines  2020-03-04          3       1          1
# 102            NaN    Philippines  2020-03-05          3       1          1
# 96             NaN    Philippines  2020-03-06          5       1          1
# 99             NaN    Philippines  2020-03-07          6       1          1
# 98             NaN    Philippines  2020-03-08         10       1          1
# 78             NaN    Philippines  2020-03-09         20       1          1
# 72             NaN    Philippines  2020-03-10         33       1          2
# 70             NaN    Philippines  2020-03-11         49       1          2
# ...

# %%
df.loc[df.Country_Region == 'Philippines', "Latitude"] = 12.8797
df.loc[df.Country_Region == 'Philippines', "Longitude"] = 121.774
df.loc[df.Country_Region == 'Philippines', "Province_State"] = 'Philippines'
df[df['Country_Region']=='Philippines']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 78     Philippines    Philippines  2020-03-01          3       1          1
# 84     Philippines    Philippines  2020-03-02          3       1          1
# 85     Philippines    Philippines  2020-03-03          3       1          1
# 94     Philippines    Philippines  2020-03-04          3       1          1
# 102    Philippines    Philippines  2020-03-05          3       1          1
# 96     Philippines    Philippines  2020-03-06          5       1          1
# 99     Philippines    Philippines  2020-03-07          6       1          1
# 98     Philippines    Philippines  2020-03-08         10       1          1
# 78     Philippines    Philippines  2020-03-09         20       1          1
# 72     Philippines    Philippines  2020-03-10         33       1          2
# 70     Philippines    Philippines  2020-03-11         49       1          2
# ...

# %%
df[df['Country_Region']=='Vietnam']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 51             NaN        Vietnam  2020-03-01         16       0         16
# 54             NaN        Vietnam  2020-03-02         16       0         16
# 56             NaN        Vietnam  2020-03-03         16       0         16
# 61             NaN        Vietnam  2020-03-04         16       0         16
# 68             NaN        Vietnam  2020-03-05         16       0         16
# 75             NaN        Vietnam  2020-03-06         16       0         16
# 74             NaN        Vietnam  2020-03-07         18       0         16
# 69             NaN        Vietnam  2020-03-08         30       0         16
# 72             NaN        Vietnam  2020-03-09         30       0         16
# 78             NaN        Vietnam  2020-03-11         38       0         16
# 81             NaN        Vietnam  2020-03-12         39       0         16
# ...

# %%
df.loc[df.Country_Region == 'Vietnam', "Latitude"] = 14.0583
df.loc[df.Country_Region == 'Vietnam', "Longitude"] = 108.2772
df.loc[df.Country_Region == 'Vietnam', "Province_State"] = 'Vietnam'
df[df['Country_Region']=='Vietnam']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 51         Vietnam        Vietnam  2020-03-01         16       0         16
# 54         Vietnam        Vietnam  2020-03-02         16       0         16
# 56         Vietnam        Vietnam  2020-03-03         16       0         16
# 61         Vietnam        Vietnam  2020-03-04         16       0         16
# 68         Vietnam        Vietnam  2020-03-05         16       0         16
# 75         Vietnam        Vietnam  2020-03-06         16       0         16
# 74         Vietnam        Vietnam  2020-03-07         18       0         16
# 69         Vietnam        Vietnam  2020-03-08         30       0         16
# 72         Vietnam        Vietnam  2020-03-09         30       0         16
# 78         Vietnam        Vietnam  2020-03-11         38       0         16
# 81         Vietnam        Vietnam  2020-03-12         39       0         16
# ...

# %%
df[df['Country_Region']=='France'].head(15)
# Out:
#        Province_State Country_Region Last_Update  Confirmed  Deaths  \
# 28                NaN         France  2020-03-01        130       2
# 23                NaN         France  2020-03-02        191       3
# 23                NaN         France  2020-03-03        204       4
# 21                NaN         France  2020-03-04        285       4
# 18                NaN         France  2020-03-05        377       6
# 13                NaN         France  2020-03-06        653       9
# 9                 NaN         France  2020-03-07        949      11
# 7                 NaN         France  2020-03-08       1126      19
# 7                 NaN         France  2020-03-09       1209      19
# 4                 NaN         France  2020-03-10       1784      33
# 4              France         France  2020-03-11       2281      48
# 170         St Martin         France  2020-03-11          2       0
# 186  Saint Barthelemy         France  2020-03-11          1       0
# ...

# %%
len(df)
# Out:
# 4743

# %%
df.loc[df.Country_Region == 'Austria', "Province_State"] = 'Austria'
df[df['Country_Region']=='Austria']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 52        Austria        Austria  2020-03-01         14       0          0
# 50        Austria        Austria  2020-03-02         18       0          0
# 51        Austria        Austria  2020-03-03         21       0          0
# 52        Austria        Austria  2020-03-04         29       0          0
# 52        Austria        Austria  2020-03-05         41       0          0
# 49        Austria        Austria  2020-03-06         55       0          0
# 44        Austria        Austria  2020-03-07         79       0          0
# 41        Austria        Austria  2020-03-08        104       0          0
# 38        Austria        Austria  2020-03-09        131       0          2
# 34        Austria        Austria  2020-03-10        182       0          4
# 34        Austria        Austria  2020-03-11        246       0          4
# ...

# %%
df[df['Country_Region']=='Belgium']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 84             NaN        Belgium  2020-03-01          2       0          1
# 63             NaN        Belgium  2020-03-02          8       0          1
# 58             NaN        Belgium  2020-03-03         13       0          1
# 56             NaN        Belgium  2020-03-04         23       0          1
# 47             NaN        Belgium  2020-03-05         50       0          1
# 37             NaN        Belgium  2020-03-06        109       0          1
# 30             NaN        Belgium  2020-03-07        169       0          1
# 30             NaN        Belgium  2020-03-08        200       0          1
# 30             NaN        Belgium  2020-03-09        239       0          1
# 29             NaN        Belgium  2020-03-10        267       0          1
# 30             NaN        Belgium  2020-03-11        314       3          1
# ...

# %%
df.loc[df.Country_Region == 'Belgium', "Latitude"] = 50.5039
df.loc[df.Country_Region == 'Belgium', "Longitude"] = 4.4699
df.loc[df.Country_Region == 'Belgium', "Province_State"] = 'Belgium'
df[df['Country_Region']=='Belgium']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 84         Belgium        Belgium  2020-03-01          2       0          1
# 63         Belgium        Belgium  2020-03-02          8       0          1
# 58         Belgium        Belgium  2020-03-03         13       0          1
# 56         Belgium        Belgium  2020-03-04         23       0          1
# 47         Belgium        Belgium  2020-03-05         50       0          1
# 37         Belgium        Belgium  2020-03-06        109       0          1
# 30         Belgium        Belgium  2020-03-07        169       0          1
# 30         Belgium        Belgium  2020-03-08        200       0          1
# 30         Belgium        Belgium  2020-03-09        239       0          1
# 29         Belgium        Belgium  2020-03-10        267       0          1
# 30         Belgium        Belgium  2020-03-11        314       3          1
# ...

# %%
df[df['Country_Region']=='Qatar']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 79             NaN          Qatar  2020-03-01          3       0          0
# 85             NaN          Qatar  2020-03-02          3       0          0
# 72             NaN          Qatar  2020-03-03          7       0          0
# 77             NaN          Qatar  2020-03-04          8       0          0
# 81             NaN          Qatar  2020-03-05          8       0          0
# 89             NaN          Qatar  2020-03-06          8       0          0
# 93             NaN          Qatar  2020-03-07          8       0          0
# 84             NaN          Qatar  2020-03-08         15       0          0
# 82             NaN          Qatar  2020-03-09         18       0          0
# 80             NaN          Qatar  2020-03-10         24       0          0
# 32             NaN          Qatar  2020-03-11        262       0          0
# ...

# %%
df.loc[df.Country_Region == 'Qatar', "Province_State"] = 'Qatar'
df[df['Country_Region']=='Qatar']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 79           Qatar          Qatar  2020-03-01          3       0          0
# 85           Qatar          Qatar  2020-03-02          3       0          0
# 72           Qatar          Qatar  2020-03-03          7       0          0
# 77           Qatar          Qatar  2020-03-04          8       0          0
# 81           Qatar          Qatar  2020-03-05          8       0          0
# 89           Qatar          Qatar  2020-03-06          8       0          0
# 93           Qatar          Qatar  2020-03-07          8       0          0
# 84           Qatar          Qatar  2020-03-08         15       0          0
# 82           Qatar          Qatar  2020-03-09         18       0          0
# 80           Qatar          Qatar  2020-03-10         24       0          0
# 32           Qatar          Qatar  2020-03-11        262       0          0
# ...

# %%
df[df['Country_Region']=='Bahrain']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 39            NaN        Bahrain  2020-03-01         47       0          0
# 40            NaN        Bahrain  2020-03-02         49       0          0
# 42            NaN        Bahrain  2020-03-03         49       0          0
# 43            NaN        Bahrain  2020-03-04         52       0          0
# 45            NaN        Bahrain  2020-03-05         55       0          0
# 46            NaN        Bahrain  2020-03-06         60       0          4
# 43            NaN        Bahrain  2020-03-07         85       0          4
# 44            NaN        Bahrain  2020-03-08         85       0          4
# 44            NaN        Bahrain  2020-03-09         95       0         14
# 47            NaN        Bahrain  2020-03-10        110       0         22
# 37            NaN        Bahrain  2020-03-11        195       0         35
# ...

# %%
df.loc[df.Country_Region == 'Bahrain', "Latitude"] = 26.0667
df.loc[df.Country_Region == 'Bahrain', "Longitude"] = 50.5577
df.loc[df.Country_Region == 'Bahrain', "Province_State"] = 'Bahrain'
df[df['Country_Region']=='Bahrain']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 39        Bahrain        Bahrain  2020-03-01         47       0          0
# 40        Bahrain        Bahrain  2020-03-02         49       0          0
# 42        Bahrain        Bahrain  2020-03-03         49       0          0
# 43        Bahrain        Bahrain  2020-03-04         52       0          0
# 45        Bahrain        Bahrain  2020-03-05         55       0          0
# 46        Bahrain        Bahrain  2020-03-06         60       0          4
# 43        Bahrain        Bahrain  2020-03-07         85       0          4
# 44        Bahrain        Bahrain  2020-03-08         85       0          4
# 44        Bahrain        Bahrain  2020-03-09         95       0         14
# 47        Bahrain        Bahrain  2020-03-10        110       0         22
# 37        Bahrain        Bahrain  2020-03-11        195       0         35
# ...

# %%
df[df['Country_Region']=='Israel']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 55            NaN         Israel  2020-03-01         10       0          1
# 58            NaN         Israel  2020-03-02         10       0          1
# 60            NaN         Israel  2020-03-03         12       0          1
# 62            NaN         Israel  2020-03-04         15       0          1
# 65            NaN         Israel  2020-03-05         16       0          1
# 63            NaN         Israel  2020-03-06         21       0          2
# 68            NaN         Israel  2020-03-07         21       0          2
# 60            NaN         Israel  2020-03-08         39       0          2
# 62            NaN         Israel  2020-03-09         39       0          2
# 59            NaN         Israel  2020-03-10         58       0          4
# 49            NaN         Israel  2020-03-11        109       0          4
# ...

# %%
df.loc[df.Country_Region == 'Israel', "Latitude"] = 31.0461
df.loc[df.Country_Region == 'Israel', "Longitude"] = 34.8516
df.loc[df.Country_Region == 'Israel', "Province_State"] = 'Israel'
df[df['Country_Region']=='Israel']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 55         Israel         Israel  2020-03-01         10       0          1
# 58         Israel         Israel  2020-03-02         10       0          1
# 60         Israel         Israel  2020-03-03         12       0          1
# 62         Israel         Israel  2020-03-04         15       0          1
# 65         Israel         Israel  2020-03-05         16       0          1
# 63         Israel         Israel  2020-03-06         21       0          2
# 68         Israel         Israel  2020-03-07         21       0          2
# 60         Israel         Israel  2020-03-08         39       0          2
# 62         Israel         Israel  2020-03-09         39       0          2
# 59         Israel         Israel  2020-03-10         58       0          4
# 49         Israel         Israel  2020-03-11        109       0          4
# ...

# %%
df.loc[df.Country_Region == 'Iceland', "Province_State"] = 'Iceland'
df[df['Country_Region']=='Iceland']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 76        Iceland        Iceland  2020-03-01          3       0          0
# 71        Iceland        Iceland  2020-03-02          6       0          0
# 63        Iceland        Iceland  2020-03-03         11       0          0
# 55        Iceland        Iceland  2020-03-04         26       0          0
# 54        Iceland        Iceland  2020-03-05         34       0          0
# 54        Iceland        Iceland  2020-03-06         43       0          0
# 52        Iceland        Iceland  2020-03-07         50       0          0
# 53        Iceland        Iceland  2020-03-08         50       0          0
# 54        Iceland        Iceland  2020-03-09         58       0          0
# 56        Iceland        Iceland  2020-03-10         69       0          1
# 54        Iceland        Iceland  2020-03-11         85       0          1
# ...

# %%
df.loc[df.Country_Region == 'Greece', "Province_State"] = 'Greece'
df[df['Country_Region']=='Greece']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 64         Greece         Greece  2020-03-01          7       0          0
# 67         Greece         Greece  2020-03-02          7       0          0
# 71         Greece         Greece  2020-03-03          7       0          0
# 75         Greece         Greece  2020-03-04          9       0          0
# 55         Greece         Greece  2020-03-05         31       0          0
# 51         Greece         Greece  2020-03-06         45       0          0
# 54         Greece         Greece  2020-03-07         46       0          0
# 50         Greece         Greece  2020-03-08         73       0          0
# 51         Greece         Greece  2020-03-09         73       0          0
# 50         Greece         Greece  2020-03-10         89       0          0
# 50         Greece         Greece  2020-03-11         99       1          0
# ...

# %%
df.loc[df.Country_Region == 'Czechia', "Province_State"] = 'Czechia'
df[df['Country_Region']=='Czechia']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 53         Czechia        Czechia  2020-03-11         91       0          0
# 53         Czechia        Czechia  2020-03-12         94       0          0
# 103        Czechia        Czechia  2020-03-13        141       0          0
# 44         Czechia        Czechia  2020-03-14        189       0          0
# 41         Czechia        Czechia  2020-03-15        253       0          0
# 38         Czechia        Czechia  2020-03-16        298       0          3
# 35         Czechia        Czechia  2020-03-17        396       0          3
# 33         Czechia        Czechia  2020-03-18        464       0          3
# 30         Czechia        Czechia  2020-03-19        694       0          3
# 28         Czechia        Czechia  2020-03-20        833       0          4
# 27         Czechia        Czechia  2020-03-21        995       0          6
#
#      Latitude  Longitude
# 53    49.8175     15.473
# ...

# %%
df.loc[df.Country_Region == 'United Arab Emirates', "Latitude"] = 23.4241
df.loc[df.Country_Region == 'United Arab Emirates', "Longitude"] = 53.8478
df.loc[df.Country_Region == 'United Arab Emirates', "Province_State"] ='United Arab Emirates'
df[df['Country_Region']=='United Arab Emirates']
# Out:
#            Province_State        Country_Region Last_Update  Confirmed  \
# 47   United Arab Emirates  United Arab Emirates  2020-03-01         21
# 49   United Arab Emirates  United Arab Emirates  2020-03-02         21
# 49   United Arab Emirates  United Arab Emirates  2020-03-03         27
# 54   United Arab Emirates  United Arab Emirates  2020-03-04         27
# 57   United Arab Emirates  United Arab Emirates  2020-03-05         29
# 57   United Arab Emirates  United Arab Emirates  2020-03-06         29
# 57   United Arab Emirates  United Arab Emirates  2020-03-07         45
# 58   United Arab Emirates  United Arab Emirates  2020-03-08         45
# 60   United Arab Emirates  United Arab Emirates  2020-03-09         45
# 54   United Arab Emirates  United Arab Emirates  2020-03-10         74
# 58   United Arab Emirates  United Arab Emirates  2020-03-11         74
# 56   United Arab Emirates  United Arab Emirates  2020-03-12         85
# ...

# %%
df[df['Country_Region']=='Kuwait']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 40            NaN         Kuwait  2020-03-01         45       0          0
# 39            NaN         Kuwait  2020-03-02         56       0          0
# 39            NaN         Kuwait  2020-03-03         56       0          0
# 41            NaN         Kuwait  2020-03-04         56       0          0
# 44            NaN         Kuwait  2020-03-05         58       0          0
# 47            NaN         Kuwait  2020-03-06         58       0          0
# 49            NaN         Kuwait  2020-03-07         61       0          0
# 51            NaN         Kuwait  2020-03-08         64       0          1
# 52            NaN         Kuwait  2020-03-09         64       0          1
# 57            NaN         Kuwait  2020-03-10         69       0          1
# 59            NaN         Kuwait  2020-03-11         72       0          2
# ...

# %%
df.loc[df.Country_Region == 'Kuwait', "Latitude"] = 29.3117
df.loc[df.Country_Region == 'Kuwait', "Longitude"] = 47.4818
df.loc[df.Country_Region == 'Kuwait', "Province_State"] = 'Kuwait'
df[df['Country_Region']=='Kuwait']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 40         Kuwait         Kuwait  2020-03-01         45       0          0
# 39         Kuwait         Kuwait  2020-03-02         56       0          0
# 39         Kuwait         Kuwait  2020-03-03         56       0          0
# 41         Kuwait         Kuwait  2020-03-04         56       0          0
# 44         Kuwait         Kuwait  2020-03-05         58       0          0
# 47         Kuwait         Kuwait  2020-03-06         58       0          0
# 49         Kuwait         Kuwait  2020-03-07         61       0          0
# 51         Kuwait         Kuwait  2020-03-08         64       0          1
# 52         Kuwait         Kuwait  2020-03-09         64       0          1
# 57         Kuwait         Kuwait  2020-03-10         69       0          1
# 59         Kuwait         Kuwait  2020-03-11         72       0          2
# ...

# %%
df[df['Country_Region']=='India']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 77             NaN          India  2020-03-01          3       0          3
# 73             NaN          India  2020-03-02          5       0          3
# 78             NaN          India  2020-03-03          5       0          3
# 53             NaN          India  2020-03-04         28       0          3
# 56             NaN          India  2020-03-05         30       0          3
# 56             NaN          India  2020-03-06         31       0          3
# 58             NaN          India  2020-03-07         34       0          3
# 59             NaN          India  2020-03-08         39       0          3
# 61             NaN          India  2020-03-09         43       0          3
# 60             NaN          India  2020-03-10         56       0          4
# 62             NaN          India  2020-03-11         62       1          4
# ...

# %%
df.loc[df.Country_Region == 'India', "Latitude"] = 20.5937
df.loc[df.Country_Region == 'India', "Longitude"] = 78.9629
df.loc[df.Country_Region == 'India', "Province_State"] = 'India'
df[df['Country_Region']=='India']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 77           India          India  2020-03-01          3       0          3
# 73           India          India  2020-03-02          5       0          3
# 78           India          India  2020-03-03          5       0          3
# 53           India          India  2020-03-04         28       0          3
# 56           India          India  2020-03-05         30       0          3
# 56           India          India  2020-03-06         31       0          3
# 58           India          India  2020-03-07         34       0          3
# 59           India          India  2020-03-08         39       0          3
# 61           India          India  2020-03-09         43       0          3
# 60           India          India  2020-03-10         56       0          4
# 62           India          India  2020-03-11         62       1          4
# ...

# %%
df[df['Country_Region']=='Iraq']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 48            NaN           Iraq  2020-03-01         19       0          0
# 47            NaN           Iraq  2020-03-02         26       0          0
# 47            NaN           Iraq  2020-03-03         32       0          0
# 49            NaN           Iraq  2020-03-04         35       2          0
# 53            NaN           Iraq  2020-03-05         35       2          0
# 55            NaN           Iraq  2020-03-06         40       3          0
# 51            NaN           Iraq  2020-03-07         54       4          0
# 52            NaN           Iraq  2020-03-08         60       6          0
# 53            NaN           Iraq  2020-03-09         60       6          9
# 55            NaN           Iraq  2020-03-10         71       7          3
# 60            NaN           Iraq  2020-03-11         71       7         15
# ...

# %%
df.loc[df.Country_Region == 'Iraq', "Latitude"] = 33.2232
df.loc[df.Country_Region == 'Iraq', "Longitude"] = 43.6793
df.loc[df.Country_Region == 'Iraq', "Province_State"] = 'Iraq'
df[df['Country_Region']=='Iraq']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 48           Iraq           Iraq  2020-03-01         19       0          0
# 47           Iraq           Iraq  2020-03-02         26       0          0
# 47           Iraq           Iraq  2020-03-03         32       0          0
# 49           Iraq           Iraq  2020-03-04         35       2          0
# 53           Iraq           Iraq  2020-03-05         35       2          0
# 55           Iraq           Iraq  2020-03-06         40       3          0
# 51           Iraq           Iraq  2020-03-07         54       4          0
# 52           Iraq           Iraq  2020-03-08         60       6          0
# 53           Iraq           Iraq  2020-03-09         60       6          9
# 55           Iraq           Iraq  2020-03-10         71       7          3
# 60           Iraq           Iraq  2020-03-11         71       7         15
# ...

# %%
df.loc[df.Country_Region == 'San Marino', "Province_State"] = 'San Marino'
df[df['Country_Region']=='San Marino']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 110     San Marino     San Marino  2020-03-01          1       0          0
# 65      San Marino     San Marino  2020-03-02          8       0          0
# 66      San Marino     San Marino  2020-03-03         10       1          0
# 60      San Marino     San Marino  2020-03-04         16       1          0
# 60      San Marino     San Marino  2020-03-05         21       1          0
# 64      San Marino     San Marino  2020-03-06         21       1          0
# 64      San Marino     San Marino  2020-03-07         23       1          0
# 63      San Marino     San Marino  2020-03-08         36       1          0
# 64      San Marino     San Marino  2020-03-09         36       1          0
# 63      San Marino     San Marino  2020-03-10         51       2          0
# 63      San Marino     San Marino  2020-03-11         62       2          0
# ...

# %%
df[df['Country_Region']=='Egypt']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 86             NaN          Egypt  2020-03-01          2       0          1
# 90             NaN          Egypt  2020-03-02          2       0          1
# 90             NaN          Egypt  2020-03-03          2       0          1
# 99             NaN          Egypt  2020-03-04          2       0          1
# 99             NaN          Egypt  2020-03-05          3       0          1
# 76             NaN          Egypt  2020-03-06         15       0          1
# 77             NaN          Egypt  2020-03-07         15       0          1
# 55             NaN          Egypt  2020-03-08         49       1          1
# 55             NaN          Egypt  2020-03-09         55       1         12
# 58             NaN          Egypt  2020-03-10         59       1          1
# 65             NaN          Egypt  2020-03-11         60       1         27
# ...

# %%
df.loc[df.Country_Region == 'Egypt', "Latitude"] = 26.8206
df.loc[df.Country_Region == 'Egypt', "Longitude"] = 30.8025
df.loc[df.Country_Region == 'Egypt', "Province_State"] = 'Egypt'
df[df['Country_Region']=='Egypt']
# Out:
#     Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 86           Egypt          Egypt  2020-03-01          2       0          1
# 90           Egypt          Egypt  2020-03-02          2       0          1
# 90           Egypt          Egypt  2020-03-03          2       0          1
# 99           Egypt          Egypt  2020-03-04          2       0          1
# 99           Egypt          Egypt  2020-03-05          3       0          1
# 76           Egypt          Egypt  2020-03-06         15       0          1
# 77           Egypt          Egypt  2020-03-07         15       0          1
# 55           Egypt          Egypt  2020-03-08         49       1          1
# 55           Egypt          Egypt  2020-03-09         55       1         12
# 58           Egypt          Egypt  2020-03-10         59       1          1
# 65           Egypt          Egypt  2020-03-11         60       1         27
# ...

# %%
df.loc[df.Country_Region == 'Iraq', "Latitude"] = 33.2232
df.loc[df.Country_Region == 'Iraq', "Longitude"] = 43.6793
df.loc[df.Country_Region == 'Iraq', "Province_State"] = 'Iraq'
df[df['Country_Region']=='Iraq']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 48           Iraq           Iraq  2020-03-01         19       0          0
# 47           Iraq           Iraq  2020-03-02         26       0          0
# 47           Iraq           Iraq  2020-03-03         32       0          0
# 49           Iraq           Iraq  2020-03-04         35       2          0
# 53           Iraq           Iraq  2020-03-05         35       2          0
# 55           Iraq           Iraq  2020-03-06         40       3          0
# 51           Iraq           Iraq  2020-03-07         54       4          0
# 52           Iraq           Iraq  2020-03-08         60       6          0
# 53           Iraq           Iraq  2020-03-09         60       6          9
# 55           Iraq           Iraq  2020-03-10         71       7          3
# 60           Iraq           Iraq  2020-03-11         71       7         15
# ...

# %%
df.loc[df.Country_Region == 'Iraq', "Latitude"] = 33.2232
df.loc[df.Country_Region == 'Iraq', "Longitude"] = 43.6793
df.loc[df.Country_Region == 'Iraq', "Province_State"] = 'Iraq'
df[df['Country_Region']=='Iraq']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 48           Iraq           Iraq  2020-03-01         19       0          0
# 47           Iraq           Iraq  2020-03-02         26       0          0
# 47           Iraq           Iraq  2020-03-03         32       0          0
# 49           Iraq           Iraq  2020-03-04         35       2          0
# 53           Iraq           Iraq  2020-03-05         35       2          0
# 55           Iraq           Iraq  2020-03-06         40       3          0
# 51           Iraq           Iraq  2020-03-07         54       4          0
# 52           Iraq           Iraq  2020-03-08         60       6          0
# 53           Iraq           Iraq  2020-03-09         60       6          9
# 55           Iraq           Iraq  2020-03-10         71       7          3
# 60           Iraq           Iraq  2020-03-11         71       7         15
# ...

# %%
df.loc[df.Country_Region == 'Iraq', "Latitude"] = 33.2232
df.loc[df.Country_Region == 'Iraq', "Longitude"] = 43.6793
df.loc[df.Country_Region == 'Iraq', "Province_State"] = 'Iraq'
df[df['Country_Region']=='Iraq']
# Out:
#    Province_State Country_Region Last_Update  Confirmed  Deaths  Recovered  \
# 48           Iraq           Iraq  2020-03-01         19       0          0
# 47           Iraq           Iraq  2020-03-02         26       0          0
# 47           Iraq           Iraq  2020-03-03         32       0          0
# 49           Iraq           Iraq  2020-03-04         35       2          0
# 53           Iraq           Iraq  2020-03-05         35       2          0
# 55           Iraq           Iraq  2020-03-06         40       3          0
# 51           Iraq           Iraq  2020-03-07         54       4          0
# 52           Iraq           Iraq  2020-03-08         60       6          0
# 53           Iraq           Iraq  2020-03-09         60       6          9
# 55           Iraq           Iraq  2020-03-10         71       7          3
# 60           Iraq           Iraq  2020-03-11         71       7         15
# ...

# %%
#export to csv
df.to_csv( "../combined2.csv", index=False, encoding='utf-8-sig')

# %%
#values = {'A': 0, 'B': 1, 'C': 2, 'D': 3}
#df.fillna(value=values)
