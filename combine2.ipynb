# %%
import os
import glob
import pandas as pd
import numpy as np
os.chdir("resources/2")

# %%
df1 = pd.read_csv('03-01-2020.csv')
df2 = pd.read_csv('03-21-2020.csv')
df1.head()
# Out:
#   Province/State  Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2020-03-01T10:13:19      66907    2761
# 1            NaN     South Korea  2020-03-01T23:43:03       3736      17
# 2            NaN           Italy  2020-03-01T23:23:02       1694      34
# 3      Guangdong  Mainland China  2020-03-01T14:13:18       1349       7
# 4          Henan  Mainland China  2020-03-01T14:13:18       1272      22
#
#    Recovered  Latitude  Longitude
# 0      31536   30.9756   112.2707
# 1         30   36.0000   128.0000
# 2         83   43.0000    12.0000
# 3       1016   23.3417   113.4244
# 4       1198   33.8820   113.6140

# %%
df1.head()
# Out:
#   Province/State  Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2020-03-01T10:13:19      66907    2761
# 1            NaN     South Korea  2020-03-01T23:43:03       3736      17
# 2            NaN           Italy  2020-03-01T23:23:02       1694      34
# 3      Guangdong  Mainland China  2020-03-01T14:13:18       1349       7
# 4          Henan  Mainland China  2020-03-01T14:13:18       1272      22
#
#    Recovered  Latitude  Longitude
# 0      31536   30.9756   112.2707
# 1         30   36.0000   128.0000
# 2         83   43.0000    12.0000
# 3       1016   23.3417   113.4244
# 4       1198   33.8820   113.6140

# %%
values = {'Province/State': 0,'Recovered': 0, 'Confirmed': 0, 'Deaths':0}
df1.fillna(value=values)
df1
# Out:
#                            Province/State  Country/Region  \
# 0                                   Hubei  Mainland China
# 1                                     NaN     South Korea
# 2                                     NaN           Italy
# 3                               Guangdong  Mainland China
# 4                                   Henan  Mainland China
# ..                                    ...             ...
# 120                             Tempe, AZ              US
# 121                 From Diamond Princess       Australia
# 122  Lackland, TX (From Diamond Princess)              US
# 123     Omaha, NE (From Diamond Princess)              US
# 124    Travis, CA (From Diamond Princess)              US
#
#              Last Update  Confirmed  Deaths  Recovered  Latitude  Longitude
# 0    2020-03-01T10:13:19      66907    2761      31536   30.9756   112.2707
# 1    2020-03-01T23:43:03       3736      17         30   36.0000   128.0000
# ...

# %%
df1['Country/Region'][13]
# Out:
# 'Mainland China'

# %%
len(df1)
# Out:
# 125

# %%
for i in range(len(df1)):
    if df1['Province/State'][i]=='Guangdong':
        print(df1['Province/State'][i])
# Out:
# Guangdong

# %%
provincelist = []
for i in range(len(df1)):
    if df1['Province/State'][i]=='NaN':
        print(df1['Province/State'][i])
        df1['Province/State'][i]=df1['Country/Region'][i]
        provincelist.append( df1['Province/State'][i])

# %%
provincelist
# Out:
# []

# %%
df1
# Out:
#                            Province/State  Country/Region  \
# 0                                   Hubei  Mainland China
# 1                                     NaN     South Korea
# 2                                     NaN           Italy
# 3                               Guangdong  Mainland China
# 4                                   Henan  Mainland China
# ..                                    ...             ...
# 120                             Tempe, AZ              US
# 121                 From Diamond Princess       Australia
# 122  Lackland, TX (From Diamond Princess)              US
# 123     Omaha, NE (From Diamond Princess)              US
# 124    Travis, CA (From Diamond Princess)              US
#
#              Last Update  Confirmed  Deaths  Recovered  Latitude  Longitude
# 0    2020-03-01T10:13:19      66907    2761      31536   30.9756   112.2707
# 1    2020-03-01T23:43:03       3736      17         30   36.0000   128.0000
# ...

# %%
for i in range(len(df1)):
    print(df1['Province/State'][i])
# Out:
# Hubei
# nan
# nan
# Guangdong
# Henan
# Zhejiang
# Hunan
# Anhui
# nan
# Jiangxi
# Shandong
# Diamond Princess cruise ship
# Jiangsu
# Chongqing
# Sichuan
# Heilongjiang
# Beijing
# Shanghai
# Hebei
# Fujian
# nan
# Guangxi
# Shaanxi
# Yunnan
# Hainan
# Guizhou
# Tianjin
# Shanxi
# nan
# nan
# Liaoning
# nan
# Hong Kong
# Jilin
# Gansu
# nan
# Xinjiang
# Inner Mongolia
# Ningxia
# nan
# nan
# Unassigned Location (From Diamond Princess)
# nan
# Taiwan
# nan
# nan
# nan
# nan
# nan
# nan
# Qinghai
# nan
# nan
# Toronto, ON
# nan
# nan
# nan
# Macau
# nan
# Queensland
# Seattle, WA
# British Columbia
# Victoria
# nan
# nan
# New South Wales
# nan
# nan
# nan
# nan
# nan
# nan
# South Australia
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Chicago, IL
# Santa Clara, CA
# Western Australia
# nan
# nan
# nan
# nan
# Sacramento County, CA
# San Benito, CA
# San Diego County, CA
# Snohomish County, WA
# nan
# nan
# nan
# nan
# nan
#  Montreal, QC
# London, ON
# nan
# nan
# nan
# nan
# ...

# %%
df3=df1[df1['Province/State'].notna()]
df4=df2[df2['Province/State'].notna()]

print (f"df3 {len(df3)}, df4:{len(df4)}")

# %%
df5 = df3.drop(['Last Update','Confirmed','Deaths','Recovered','Country/Region'], axis =1)
df6 = df4.drop(columns =['Last Update','Confirmed','Deaths','Recovered','Country/Region'] )
df6.head()

# %%
df5.to_csv( "../Pcoordinators1.csv", index=False, encoding='utf-8-sig')
df6.to_csv( "../Pcoordinators2.csv", index=False, encoding='utf-8-sig')

# %%
#Use glob to match the pattern ‘csv’
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format('csv'))]
#Combine all files in the list
df = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
df.rename(columns={'Last Update':'Last_Update','Province/State':'Province_State','Country/Region':'Country_Region'}, inplace=True) 
df.head(2)

# %%
#mar['Row_Num'] = np.arange(len(mar))
len(df)

# %%
df5 = pd.concat([df3, df4])
df5.head(3)

# %%
#export to csv
df.to_csv( "../combined2.csv", index=False, encoding='utf-8-sig')
